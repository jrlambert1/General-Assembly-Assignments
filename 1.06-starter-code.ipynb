# %% [markdown]
# # SQL Lab
#
# In this lab we will learn how to use execute SQL from the iPython notebook and practice some queries on the [Northwind sample database](https://northwinddatabase.codeplex.com/).
#
# You can access the data with this command:
#
#     psql -h dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com -p 5432 -U dsi_student northwind
#     password: gastudents

# %% [markdown]
# First of all let's install the ipython-sql extension. You can find instructions [here](https://github.com/catherinedevlin/ipython-sql).

# %%
# Necessary package 1 (if not already installed)
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages
# Requirement already satisfied: prettytable in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: ipython>=1.0 in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: sqlparse in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: six in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: setuptools>=18.5 in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython>=1.0->ipython-sql)
# Requirement already satisfied: jedi>=0.10 in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython>=1.0->ipython-sql)
# Requirement already satisfied: decorator in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython>=1.0->ipython-sql)
# Requirement already satisfied: pickleshare in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython>=1.0->ipython-sql)
# Requirement already satisfied: simplegeneric>0.8 in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython>=1.0->ipython-sql)
# Requirement already satisfied: traitlets>=4.2 in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython>=1.0->ipython-sql)
# Requirement already satisfied: prompt_toolkit<2.0.0,>=1.0.4 in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython>=1.0->ipython-sql)
# Requirement already satisfied: pygments in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython>=1.0->ipython-sql)
# Requirement already satisfied: appnope in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython>=1.0->ipython-sql)
# Requirement already satisfied: pexpect in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from ipython>=1.0->ipython-sql)
# Requirement already satisfied: parso==0.1.* in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql)
# Requirement already satisfied: wcwidth in /Users/slevin886/anaconda2/envs/python3/lib/python3.6/site-packages (from prompt_toolkit<2.0.0,>=1.0.4->ipython>=1.0->ipython-sql)

# %%
# Necessary package 2 (if not already installed)
# !pip install psycopg2

# %% [markdown]
# Let's see if it works:

# %%
# Magic Function Load Extension
# %load_ext sql

# %%
# Line Magic Function SQL Extension and path w/ access info to datafile

# %%
# %sql postgresql://dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# Out:
# 'Connected: dsi_student@northwind'

# %%
# This code will not run. Unfortunately, it seems that you can't run cell magic in cells that have comments. This
# does make sense, given that # are not the SQL syntax for commenting. Also, SQL comments don't seem to work
# in Jupyter notebook. Weird.

# %%sql
SELECT * 
FROM orders 
LIMIT 5;
# Out:
#   File "<ipython-input-4-e56ef27c3914>", line 5
#     %%sql
#     ^
# SyntaxError: invalid syntax

# %%
# So try to comment in cells above or below your code. Either use comments, like this cell...

# %% [markdown]
# ...or create a Markdown cell, like this cell!

# %%
# %%sql
# SELECT *
# FROM orders
# LIMIT 5;
# Out:
# 5 rows affected.
# [(10248, 'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France'),
#  (10249, 'TOMSP', 6, datetime.date(1996, 7, 5), datetime.date(1996, 8, 16), datetime.date(1996, 7, 10), 1, 11.61, 'Toms Spezialitäten', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany'),
#  (10250, 'HANAR', 4, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 12), 2, 65.83, 'Hanari Carnes', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil'),
#  (10251, 'VICTE', 3, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 15), 1, 41.34, 'Victuailles en stock', '2, rue du Commerce', 'Lyon', None, '69004', 'France'),
#  (10252, 'SUPRD', 4, datetime.date(1996, 7, 9), datetime.date(1996, 8, 6), datetime.date(1996, 7, 11), 2, 51.3, 'Suprêmes délices', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium')]

# %% [markdown]
# Nice!!! We can now go ahead with the lab!

# %% [markdown]
# ## 1: Inspect the database
#
# If we were connected via console, it would be easy to list all tables using `\dt`. We can however access table information performing a query on the `information_schema.tables` table.
#
# ### 1.a: List Tables
#
# 1. write a `SELECT` statement that lists all the tables in the public schema of the `northwind` database, sorted alphabetically

# %%
# %%SQL earlier picked our postgres filepath so we just have to call %%sql to reach our DB

# %%
# %%sql
# SELECT data_type, table_name FROM information_schema.columns ORDER BY table_name;
# Out:
# 1825 rows affected.
# [('character varying', 'administrable_role_authorizations'),
#  ('character varying', 'administrable_role_authorizations'),
#  ('character varying', 'administrable_role_authorizations'),
#  ('character varying', 'applicable_roles'),
#  ('character varying', 'applicable_roles'),
#  ('character varying', 'applicable_roles'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('integer', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('integer', 'attributes'),
#  ('integer', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('integer', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('integer', 'attributes'),
#  ('integer', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('integer', 'attributes'),
#  ('integer', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('character varying', 'attributes'),
#  ('integer', 'attributes'),
#  ('bytea', 'categories'),
#  ('text', 'categories'),
#  ('character varying', 'categories'),
#  ('smallint', 'categories'),
#  ('bigint', 'categoriesmerged'),
#  ('bigint', 'categoriesmerged'),
#  ('text', 'categoriesmerged'),
#  ('text', 'categoriesmerged'),
#  ('text', 'categoriesmerged'),
#  ('bigint', 'categoriesmerged'),
#  ('bigint', 'categoriesmerged'),
#  ('bigint', 'categoriesmerged'),
#  ('bigint', 'categoriesmerged'),
#  ('text', 'categoriesmerged'),
#  ('bigint', 'categoriesmerged'),
#  ('bigint', 'categoriesmerged'),
#  ('text', 'categoriesmerged'),
#  ('double precision', 'categoriesmerged'),
#  ('text', 'categories_pd'),
#  ('bigint', 'categories_pd'),
#  ('text', 'categories_pd'),
#  ('text', 'categories_pd'),
#  ('bigint', 'categories_pd'),
#  ('character varying', 'character_sets'),
#  ('character varying', 'character_sets'),
#  ('character varying', 'character_sets'),
#  ('character varying', 'character_sets'),
#  ('character varying', 'character_sets'),
#  ('character varying', 'character_sets'),
#  ('character varying', 'character_sets'),
#  ('character varying', 'character_sets'),
#  ('character varying', 'check_constraint_routine_usage'),
#  ('character varying', 'check_constraint_routine_usage'),
#  ('character varying', 'check_constraint_routine_usage'),
#  ('character varying', 'check_constraint_routine_usage'),
#  ('character varying', 'check_constraint_routine_usage'),
#  ('character varying', 'check_constraint_routine_usage'),
#  ('character varying', 'check_constraints'),
#  ('character varying', 'check_constraints'),
#  ('character varying', 'check_constraints'),
#  ('character varying', 'check_constraints'),
#  ('character varying', 'collation_character_set_applicability'),
#  ('character varying', 'collation_character_set_applicability'),
#  ('character varying', 'collation_character_set_applicability'),
#  ('character varying', 'collation_character_set_applicability'),
#  ('character varying', 'collation_character_set_applicability'),
#  ('character varying', 'collation_character_set_applicability'),
#  ('character varying', 'collations'),
#  ('character varying', 'collations'),
#  ('character varying', 'collations'),
#  ('character varying', 'collations'),
#  ('character varying', 'column_domain_usage'),
#  ('character varying', 'column_domain_usage'),
#  ('character varying', 'column_domain_usage'),
#  ('character varying', 'column_domain_usage'),
#  ('character varying', 'column_domain_usage'),
#  ('character varying', 'column_domain_usage'),
#  ('character varying', 'column_domain_usage'),
#  ('name', 'column_options'),
#  ('character varying', 'column_options'),
#  ('character varying', 'column_options'),
#  ('name', 'column_options'),
#  ('name', 'column_options'),
#  ('character varying', 'column_options'),
#  ('character varying', 'column_privileges'),
#  ('character varying', 'column_privileges'),
#  ('character varying', 'column_privileges'),
#  ('character varying', 'column_privileges'),
#  ('character varying', 'column_privileges'),
#  ('character varying', 'column_privileges'),
#  ('character varying', 'column_privileges'),
#  ('character varying', 'column_privileges'),
#  ('integer', 'columns'),
#  ('integer', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('integer', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('integer', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('character varying', 'columns'),
#  ('integer', 'columns'),
#  ('integer', 'columns'),
#  ('integer', 'columns'),
#  ('integer', 'columns'),
#  ('integer', 'columns'),
#  ('character varying', 'column_udt_usage'),
#  ('character varying', 'column_udt_usage'),
#  ('character varying', 'column_udt_usage'),
#  ('character varying', 'column_udt_usage'),
#  ('character varying', 'column_udt_usage'),
#  ('character varying', 'column_udt_usage'),
#  ('character varying', 'column_udt_usage'),
#  ('character varying', 'constraint_column_usage'),
#  ('character varying', 'constraint_column_usage'),
#  ('character varying', 'constraint_column_usage'),
#  ('character varying', 'constraint_column_usage'),
#  ('character varying', 'constraint_column_usage'),
#  ('character varying', 'constraint_column_usage'),
#  ('character varying', 'constraint_column_usage'),
#  ('character varying', 'constraint_table_usage'),
#  ('character varying', 'constraint_table_usage'),
#  ('character varying', 'constraint_table_usage'),
#  ('character varying', 'constraint_table_usage'),
#  ('character varying', 'constraint_table_usage'),
#  ('character varying', 'constraint_table_usage'),
#  ('integer', 'credit_card_feature'),
#  ('bigint', 'credit_card_feature'),
#  ('character varying', 'credit_card_feature'),
#  ('integer', 'credit_card_feature'),
#  ('character', 'customercustomerdemo'),
#  ('character', 'customercustomerdemo'),
#  ('text', 'customerdemographics'),
#  ('character', 'customerdemographics'),
#  ('character varying', 'customers'),
#  ('character varying', 'customers'),
#  ('character varying', 'customers'),
#  ('character varying', 'customers'),
#  ('character varying', 'customers'),
#  ('character', 'customers'),
#  ('character varying', 'customers'),
#  ('character varying', 'customers'),
#  ('character varying', 'customers'),
#  ('character varying', 'customers'),
#  ('character varying', 'customers'),
#  ('character varying', 'data_type_privileges'),
#  ('character varying', 'data_type_privileges'),
#  ('character varying', 'data_type_privileges'),
#  ('character varying', 'data_type_privileges'),
#  ('character varying', 'data_type_privileges'),
#  ('character', 'descriptions'),
#  ('character', 'descriptions'),
#  ('character varying', 'descriptions'),
#  ('character', 'descriptions1'),
#  ('character', 'descriptions1'),
#  ('character varying', 'descriptions1'),
#  ('character', 'descriptions2'),
#  ('character', 'descriptions2'),
#  ('character varying', 'descriptions2'),
#  ('character varying', 'domain_constraints'),
#  ('character varying', 'domain_constraints'),
#  ('character varying', 'domain_constraints'),
#  ('character varying', 'domain_constraints'),
#  ('character varying', 'domain_constraints'),
#  ('character varying', 'domain_constraints'),
#  ('character varying', 'domain_constraints'),
#  ('character varying', 'domain_constraints'),
#  ('integer', 'domains'),
#  ('integer', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('integer', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('integer', 'domains'),
#  ('character varying', 'domains'),
#  ('integer', 'domains'),
#  ('integer', 'domains'),
#  ('integer', 'domains'),
#  ('integer', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domains'),
#  ('character varying', 'domain_udt_usage'),
#  ('character varying', 'domain_udt_usage'),
#  ('character varying', 'domain_udt_usage'),
#  ('character varying', 'domain_udt_usage'),
#  ('character varying', 'domain_udt_usage'),
#  ('character varying', 'domain_udt_usage'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('integer', 'element_types'),
#  ('integer', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('integer', 'element_types'),
#  ('integer', 'element_types'),
#  ('integer', 'element_types'),
#  ('integer', 'element_types'),
#  ('character varying', 'element_types'),
#  ('integer', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'element_types'),
#  ('integer', 'element_types'),
#  ('character varying', 'element_types'),
#  ('character varying', 'employees'),
#  ('smallint', 'employees'),
#  ('text', 'employees'),
#  ('bytea', 'employees'),
#  ('character varying', 'employees'),
#  ('character varying', 'employees'),
#  ('character varying', 'employees'),
#  ('character varying', 'employees'),
#  ('character varying', 'employees'),
#  ('character varying', 'employees'),
#  ('character varying', 'employees'),
#  ('date', 'employees'),
#  ('date', 'employees'),
#  ('character varying', 'employees'),
#  ('character varying', 'employees'),
#  ('character varying', 'employees'),
#  ('character varying', 'employees'),
#  ('smallint', 'employees'),
#  ('character varying', 'employeeterritories'),
#  ('smallint', 'employeeterritories'),
#  ('smallint', 'empterid'),
#  ('character varying', 'empterid'),
#  ('character varying', 'empterid2'),
#  ('smallint', 'empterid2'),
#  ('character varying', 'enabled_roles'),
#  ('character', 'final'),
#  ('character varying', 'final'),
#  ('smallint', 'final'),
#  ('smallint', 'final'),
#  ('real', 'final'),
#  ('character', 'final'),
#  ('smallint', 'final'),
#  ('character', 'final2'),
#  ('character', 'final2'),
#  ('character varying', 'final2'),
#  ('smallint', 'final2'),
#  ('real', 'final2'),
#  ('smallint', 'final2'),
#  ('smallint', 'final2'),
#  ('smallint', 'final3'),
#  ('character', 'final3'),
#  ('smallint', 'final3'),
#  ('real', 'final3'),
#  ('smallint', 'final3'),
#  ('character', 'final3'),
#  ('character', 'final4'),
#  ('real', 'final4'),
#  ('character', 'final4'),
#  ('smallint', 'final4'),
#  ('smallint', 'final4'),
#  ('smallint', 'final4'),
#  ('character', 'final5'),
#  ('smallint', 'final5'),
#  ('smallint', 'final5'),
#  ('real', 'final5'),
#  ('smallint', 'final5'),
#  ('character', 'final5'),
#  ('smallint', 'fo'),
#  ('character', 'fo'),
#  ('character', 'fo'),
#  ('smallint', 'fo'),
#  ('real', 'fo'),
#  ('smallint', 'fo'),
#  ('character varying', 'foreign_data_wrapper_options'),
#  ('character varying', 'foreign_data_wrapper_options'),
#  ('character varying', 'foreign_data_wrapper_options'),
#  ('character varying', 'foreign_data_wrapper_options'),
#  ('character varying', 'foreign_data_wrappers'),
#  ('character varying', 'foreign_data_wrappers'),
#  ('character varying', 'foreign_data_wrappers'),
#  ('character varying', 'foreign_data_wrappers'),
#  ('character varying', 'foreign_data_wrappers'),
#  ('character varying', 'foreign_server_options'),
#  ('character varying', 'foreign_server_options'),
#  ('character varying', 'foreign_server_options'),
#  ('character varying', 'foreign_server_options'),
#  ('character varying', 'foreign_servers'),
#  ('character varying', 'foreign_servers'),
#  ('character varying', 'foreign_servers'),
#  ('character varying', 'foreign_servers'),
#  ('character varying', 'foreign_servers'),
#  ('character varying', 'foreign_servers'),
#  ('character varying', 'foreign_servers'),
#  ('character varying', 'foreign_table_options'),
#  ('name', 'foreign_table_options'),
#  ('name', 'foreign_table_options'),
#  ('character varying', 'foreign_table_options'),
#  ('character varying', 'foreign_table_options'),
#  ('character varying', 'foreign_tables'),
#  ('name', 'foreign_tables'),
#  ('character varying', 'foreign_tables'),
#  ('character varying', 'foreign_tables'),
#  ('name', 'foreign_tables'),
#  ('character', 'full_ord'),
#  ('character', 'full_ord'),
#  ('smallint', 'full_ord'),
#  ('real', 'full_ord'),
#  ('smallint', 'full_ord'),
#  ('smallint', 'full_ord'),
#  ('smallint', 'full_ord'),
#  ('smallint', 'full_order'),
#  ('character', 'full_order'),
#  ('character', 'full_order'),
#  ('smallint', 'full_order'),
#  ('smallint', 'full_order'),
#  ('real', 'full_order'),
#  ('smallint', 'full_order'),
#  ('smallint', 'fullorders'),
#  ('real', 'fullorders'),
#  ('smallint', 'fullorders'),
#  ('smallint', 'fullorders'),
#  ('character', 'fullorders'),
#  ('character', 'fullorders'),
#  ('smallint', 'fullorders'),
#  ('character', 'full_orders_'),
#  ('character', 'full_orders_'),
#  ('smallint', 'full_orders_'),
#  ('smallint', 'full_orders_'),
#  ('smallint', 'full_orders_'),
#  ('real', 'full_orders_'),
#  ('smallint', 'full_orders_'),
#  ('smallint', 'fullorders_'),
#  ('smallint', 'fullorders_'),
#  ('character', 'fullorders_'),
#  ('character', 'fullorders_'),
#  ('smallint', 'fullorders_'),
#  ('smallint', 'fullorders_'),
#  ('real', 'fullorders_'),
#  ('character', 'fullorders__'),
#  ('smallint', 'fullorders__'),
#  ('real', 'fullorders__'),
#  ('smallint', 'fullorders__'),
#  ('smallint', 'fullorders__'),
#  ('character', 'fullorders__'),
#  ('smallint', 'fullorders__'),
#  ('smallint', 'full_order_table'),
#  ('character', 'full_order_table'),
#  ('character', 'full_order_table'),
#  ('real', 'full_order_table'),
#  ('smallint', 'full_order_table'),
#  ('smallint', 'full_order_table'),
#  ('real', 'full_order_table2'),
#  ('smallint', 'full_order_table2'),
#  ('smallint', 'full_order_table2'),
#  ('character', 'full_order_table2'),
#  ('character', 'full_order_table2'),
#  ('smallint', 'full_order_table2'),
#  ('smallint', 'full_order_table3'),
#  ('smallint', 'full_order_table3'),
#  ('smallint', 'full_order_table3'),
#  ('real', 'full_order_table3'),
#  ('character', 'full_order_table3'),
#  ('character', 'full_order_table3'),
#  ('character', 'full_order_table4'),
#  ('smallint', 'full_order_table4'),
#  ('real', 'full_order_table4'),
#  ('smallint', 'full_order_table4'),
#  ('character', 'full_order_table4'),
#  ('smallint', 'full_order_table4'),
#  ('smallint', 'full_order_table5'),
#  ('character', 'full_order_table5'),
#  ('character', 'full_order_table5'),
#  ('smallint', 'full_order_table5'),
#  ('real', 'full_order_table5'),
#  ('smallint', 'full_order_table5'),
#  ('integer', 'google_app'),
#  ('integer', 'google_app'),
#  ('integer', 'google_app'),
#  ('character varying', 'google_app'),
#  ('character varying', 'information_schema_catalog_name'),
#  ('character varying', 'key_column_usage'),
#  ('character varying', 'key_column_usage'),
#  ('character varying', 'key_column_usage'),
#  ('character varying', 'key_column_usage'),
#  ('character varying', 'key_column_usage'),
#  ('integer', 'key_column_usage'),
#  ('integer', 'key_column_usage'),
#  ('character varying', 'key_column_usage'),
#  ('character varying', 'key_column_usage'),
#  ('text', 'movies'),
#  ('double precision', 'movies'),
#  ('text', 'movies'),
#  ('text', 'movies'),
#  ('text', 'movies'),
#  ('double precision', 'movies'),
#  ('bigint', 'movies'),
#  ('bigint', 'movies'),
#  ('character', 'my_table'),
#  ('character', 'my_table'),
#  ('real', 'my_table'),
#  ('smallint', 'my_table'),
#  ('smallint', 'my_table'),
#  ('smallint', 'my_table'),
#  ('smallint', 'my_table'),
#  ('integer', 'newregion'),
#  ('character varying', 'newregion'),
#  ('character', 'new_table'),
#  ('smallint', 'new_table'),
#  ('smallint', 'new_table'),
#  ('character', 'new_table'),
#  ('real', 'new_table'),
#  ('smallint', 'new_table'),
#  ('smallint', 'order_details'),
#  ('real', 'order_details'),
#  ('smallint', 'order_details'),
#  ('real', 'order_details'),
#  ('smallint', 'order_details'),
#  ('real', 'order_details_temp'),
#  ('smallint', 'order_details_temp'),
#  ('smallint', 'order_details_temp'),
#  ('real', 'order_details_temp'),
#  ('smallint', 'order_details_temp'),
#  ('character varying', 'orders'),
#  ('real', 'orders'),
#  ('character varying', 'orders'),
#  ('character varying', 'orders'),
#  ('character varying', 'orders'),
#  ('character varying', 'orders'),
#  ('character varying', 'orders'),
#  ('smallint', 'orders'),
#  ('character', 'orders'),
#  ('smallint', 'orders'),
#  ('date', 'orders'),
#  ('date', 'orders'),
#  ('date', 'orders'),
#  ('smallint', 'orders'),
#  ('smallint', 'order_table'),
#  ('character', 'order_table'),
#  ('smallint', 'order_table'),
#  ('character', 'order_table'),
#  ('smallint', 'order_table'),
#  ('real', 'order_table'),
#  ('integer', 'parameters'),
#  ('integer', 'parameters'),
#  ('character varying', 'parameters'),
#  ('integer', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('integer', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('integer', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('integer', 'parameters'),
#  ('integer', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('character varying', 'parameters'),
#  ('integer', 'parameters'),
#  ('integer', 'parameters'),
#  ('integer', 'payments'),
#  ('date', 'payments'),
#  ('integer', 'payments'),
#  ('integer', 'payments'),
#  ('regproc', 'pg_aggregate'),
#  ('regproc', 'pg_aggregate'),
#  ('"char"', 'pg_aggregate'),
#  ('oid', 'pg_aggregate'),
#  ('integer', 'pg_aggregate'),
#  ('text', 'pg_aggregate'),
#  ('text', 'pg_aggregate'),
#  ('smallint', 'pg_aggregate'),
#  ('regproc', 'pg_aggregate'),
#  ('regproc', 'pg_aggregate'),
#  ('regproc', 'pg_aggregate'),
#  ('regproc', 'pg_aggregate'),
#  ('boolean', 'pg_aggregate'),
#  ('boolean', 'pg_aggregate'),
#  ('oid', 'pg_aggregate'),
#  ('oid', 'pg_aggregate'),
#  ('integer', 'pg_aggregate'),
#  ('boolean', 'pg_am'),
#  ('boolean', 'pg_am'),
#  ('boolean', 'pg_am'),
#  ('boolean', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('oid', 'pg_am'),
#  ('boolean', 'pg_am'),
#  ('boolean', 'pg_am'),
#  ('smallint', 'pg_am'),
#  ('smallint', 'pg_am'),
#  ('name', 'pg_am'),
#  ('boolean', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('boolean', 'pg_am'),
#  ('boolean', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('boolean', 'pg_am'),
#  ('regproc', 'pg_am'),
#  ('boolean', 'pg_am'),
#  ('oid', 'pg_amop'),
#  ('oid', 'pg_amop'),
#  ('oid', 'pg_amop'),
#  ('oid', 'pg_amop'),
#  ('oid', 'pg_amop'),
#  ('smallint', 'pg_amop'),
#  ('"char"', 'pg_amop'),
#  ('oid', 'pg_amop'),
#  ('oid', 'pg_amproc'),
#  ('regproc', 'pg_amproc'),
#  ('smallint', 'pg_amproc'),
#  ('oid', 'pg_amproc'),
#  ('oid', 'pg_amproc'),
#  ('oid', 'pg_attrdef'),
#  ('smallint', 'pg_attrdef'),
#  ('pg_node_tree', 'pg_attrdef'),
#  ('text', 'pg_attrdef'),
#  ('integer', 'pg_attribute'),
#  ('ARRAY', 'pg_attribute'),
#  ('oid', 'pg_attribute'),
#  ('name', 'pg_attribute'),
#  ('oid', 'pg_attribute'),
#  ('smallint', 'pg_attribute'),
#  ('smallint', 'pg_attribute'),
#  ('integer', 'pg_attribute'),
#  ('integer', 'pg_attribute'),
#  ('integer', 'pg_attribute'),
#  ('boolean', 'pg_attribute'),
#  ('"char"', 'pg_attribute'),
#  ('"char"', 'pg_attribute'),
#  ('boolean', 'pg_attribute'),
#  ('boolean', 'pg_attribute'),
#  ('boolean', 'pg_attribute'),
#  ('boolean', 'pg_attribute'),
#  ('integer', 'pg_attribute'),
#  ('oid', 'pg_attribute'),
#  ('ARRAY', 'pg_attribute'),
#  ('ARRAY', 'pg_attribute'),
#  ('oid', 'pg_auth_members'),
#  ('oid', 'pg_auth_members'),
#  ('oid', 'pg_auth_members'),
#  ('boolean', 'pg_auth_members'),
#  ('text', 'pg_available_extensions'),
#  ('name', 'pg_available_extensions'),
#  ('text', 'pg_available_extensions'),
#  ('text', 'pg_available_extensions'),
#  ('name', 'pg_available_extension_versions'),
#  ('ARRAY', 'pg_available_extension_versions'),
#  ('text', 'pg_available_extension_versions'),
#  ('boolean', 'pg_available_extension_versions'),
#  ('boolean', 'pg_available_extension_versions'),
#  ('text', 'pg_available_extension_versions'),
#  ('boolean', 'pg_available_extension_versions'),
#  ('name', 'pg_available_extension_versions'),
#  ('"char"', 'pg_cast'),
#  ('oid', 'pg_cast'),
#  ('oid', 'pg_cast'),
#  ('"char"', 'pg_cast'),
#  ('oid', 'pg_cast'),
#  ('oid', 'pg_class'),
#  ('name', 'pg_class'),
#  ('oid', 'pg_class'),
#  ('oid', 'pg_class'),
#  ('oid', 'pg_class'),
#  ('oid', 'pg_class'),
#  ('oid', 'pg_class'),
#  ('oid', 'pg_class'),
#  ('integer', 'pg_class'),
#  ('real', 'pg_class'),
#  ('integer', 'pg_class'),
#  ('oid', 'pg_class'),
#  ('boolean', 'pg_class'),
#  ('boolean', 'pg_class'),
#  ('"char"', 'pg_class'),
#  ('"char"', 'pg_class'),
#  ('smallint', 'pg_class'),
#  ('smallint', 'pg_class'),
#  ('boolean', 'pg_class'),
#  ('boolean', 'pg_class'),
#  ('boolean', 'pg_class'),
#  ('boolean', 'pg_class'),
#  ('boolean', 'pg_class'),
#  ('boolean', 'pg_class'),
#  ('"char"', 'pg_class'),
#  ('xid', 'pg_class'),
#  ('xid', 'pg_class'),
#  ('ARRAY', 'pg_class'),
#  ('ARRAY', 'pg_class'),
#  ('name', 'pg_collation'),
#  ('oid', 'pg_collation'),
#  ('name', 'pg_collation'),
#  ('name', 'pg_collation'),
#  ('integer', 'pg_collation'),
#  ('oid', 'pg_collation'),
#  ('ARRAY', 'pg_constraint'),
#  ('"char"', 'pg_constraint'),
#  ('"char"', 'pg_constraint'),
#  ('"char"', 'pg_constraint'),
#  ('boolean', 'pg_constraint'),
#  ('integer', 'pg_constraint'),
#  ('boolean', 'pg_constraint'),
#  ('ARRAY', 'pg_constraint'),
#  ('ARRAY', 'pg_constraint'),
#  ('ARRAY', 'pg_constraint'),
#  ('ARRAY', 'pg_constraint'),
#  ('text', 'pg_constraint'),
#  ('pg_node_tree', 'pg_constraint'),
#  ('ARRAY', 'pg_constraint'),
#  ('name', 'pg_constraint'),
#  ('oid', 'pg_constraint'),
#  ('"char"', 'pg_constraint'),
#  ('boolean', 'pg_constraint'),
#  ('boolean', 'pg_constraint'),
#  ('boolean', 'pg_constraint'),
#  ('oid', 'pg_constraint'),
#  ('oid', 'pg_constraint'),
#  ('oid', 'pg_constraint'),
#  ('oid', 'pg_constraint'),
#  ('oid', 'pg_conversion'),
#  ('oid', 'pg_conversion'),
#  ('name', 'pg_conversion'),
#  ('integer', 'pg_conversion'),
#  ('integer', 'pg_conversion'),
#  ('regproc', 'pg_conversion'),
#  ('boolean', 'pg_conversion'),
#  ('text', 'pg_cursors'),
#  ('text', 'pg_cursors'),
#  ('boolean', 'pg_cursors'),
#  ('boolean', 'pg_cursors'),
#  ('timestamp with time zone', 'pg_cursors'),
#  ('boolean', 'pg_cursors'),
#  ('oid', 'pg_database'),
#  ('integer', 'pg_database'),
#  ('boolean', 'pg_database'),
#  ('boolean', 'pg_database'),
#  ('name', 'pg_database'),
#  ('name', 'pg_database'),
#  ('integer', 'pg_database'),
#  ('oid', 'pg_database'),
#  ('name', 'pg_database'),
#  ('ARRAY', 'pg_database'),
#  ('oid', 'pg_database'),
#  ('xid', 'pg_database'),
#  ('xid', 'pg_database'),
#  ('oid', 'pg_db_role_setting'),
#  ('ARRAY', 'pg_db_role_setting'),
#  ('oid', 'pg_db_role_setting'),
#  ('oid', 'pg_default_acl'),
#  ('ARRAY', 'pg_default_acl'),
#  ('"char"', 'pg_default_acl'),
#  ('oid', 'pg_default_acl'),
#  ('"char"', 'pg_depend'),
#  ('oid', 'pg_depend'),
#  ('integer', 'pg_depend'),
#  ('oid', 'pg_depend'),
#  ('oid', 'pg_depend'),
#  ('oid', 'pg_depend'),
#  ('integer', 'pg_depend'),
#  ('integer', 'pg_description'),
#  ('oid', 'pg_description'),
#  ('oid', 'pg_description'),
#  ('text', 'pg_description'),
#  ('name', 'pg_enum'),
#  ('real', 'pg_enum'),
#  ('oid', 'pg_enum'),
#  ('oid', 'pg_event_trigger'),
#  ('name', 'pg_event_trigger'),
#  ('name', 'pg_event_trigger'),
#  ('ARRAY', 'pg_event_trigger'),
#  ('"char"', 'pg_event_trigger'),
#  ('oid', 'pg_event_trigger'),
#  ('name', 'pg_extension'),
#  ('oid', 'pg_extension'),
#  ('ARRAY', 'pg_extension'),
#  ('ARRAY', 'pg_extension'),
#  ('text', 'pg_extension'),
#  ('boolean', 'pg_extension'),
#  ('oid', 'pg_extension'),
#  ('oid', 'pg_foreign_data_wrapper'),
#  ('name', 'pg_foreign_data_wrapper'),
#  ('ARRAY', 'pg_foreign_data_wrapper'),
#  ('ARRAY', 'pg_foreign_data_wrapper'),
#  ('oid', 'pg_foreign_data_wrapper'),
#  ('oid', 'pg_foreign_data_wrapper'),
#  ('ARRAY', 'pg_foreign_server'),
#  ('ARRAY', 'pg_foreign_server'),
#  ('name', 'pg_foreign_server'),
#  ('oid', 'pg_foreign_server'),
#  ('oid', 'pg_foreign_server'),
#  ('text', 'pg_foreign_server'),
#  ('text', 'pg_foreign_server'),
#  ('ARRAY', 'pg_foreign_table'),
#  ('oid', 'pg_foreign_table'),
#  ('oid', 'pg_foreign_table'),
#  ('name', 'pg_group'),
#  ('oid', 'pg_group'),
#  ('ARRAY', 'pg_group'),
#  ('oid', 'pg_index'),
#  ('pg_node_tree', 'pg_index'),
#  ('pg_node_tree', 'pg_index'),
#  ('ARRAY', 'pg_index'),
#  ('ARRAY', 'pg_index'),
#  ('ARRAY', 'pg_index'),
#  ('ARRAY', 'pg_index'),
#  ('boolean', 'pg_index'),
#  ('boolean', 'pg_index'),
#  ('boolean', 'pg_index'),
#  ('boolean', 'pg_index'),
#  ('boolean', 'pg_index'),
#  ('boolean', 'pg_index'),
#  ('boolean', 'pg_index'),
#  ('boolean', 'pg_index'),
#  ('boolean', 'pg_index'),
#  ('boolean', 'pg_index'),
#  ('smallint', 'pg_index'),
#  ('oid', 'pg_index'),
#  ('name', 'pg_indexes'),
#  ('text', 'pg_indexes'),
#  ('name', 'pg_indexes'),
#  ('name', 'pg_indexes'),
#  ('name', 'pg_indexes'),
#  ('integer', 'pg_inherits'),
#  ('oid', 'pg_inherits'),
#  ('oid', 'pg_inherits'),
#  ('oid', 'pg_language'),
#  ('name', 'pg_language'),
#  ('oid', 'pg_language'),
#  ('oid', 'pg_language'),
#  ('oid', 'pg_language'),
#  ('ARRAY', 'pg_language'),
#  ('boolean', 'pg_language'),
#  ('boolean', 'pg_language'),
#  ('ARRAY', 'pg_largeobject_metadata'),
#  ('oid', 'pg_largeobject_metadata'),
#  ('text', 'pg_locks'),
#  ('xid', 'pg_locks'),
#  ('oid', 'pg_locks'),
#  ('oid', 'pg_locks'),
#  ('oid', 'pg_locks'),
#  ('text', 'pg_locks'),
#  ('text', 'pg_locks'),
#  ('boolean', 'pg_locks'),
#  ('boolean', 'pg_locks'),
#  ('text', 'pg_locks'),
#  ('integer', 'pg_locks'),
#  ('smallint', 'pg_locks'),
#  ('oid', 'pg_locks'),
#  ('integer', 'pg_locks'),
#  ('smallint', 'pg_locks'),
#  ('name', 'pg_matviews'),
#  ('name', 'pg_matviews'),
#  ('name', 'pg_matviews'),
#  ('boolean', 'pg_matviews'),
#  ('boolean', 'pg_matviews'),
#  ('text', 'pg_matviews'),
#  ('name', 'pg_matviews'),
#  ('oid', 'pg_namespace'),
#  ('name', 'pg_namespace'),
#  ('ARRAY', 'pg_namespace'),
#  ('oid', 'pg_opclass'),
#  ('oid', 'pg_opclass'),
#  ('oid', 'pg_opclass'),
#  ('oid', 'pg_opclass'),
#  ('boolean', 'pg_opclass'),
#  ('name', 'pg_opclass'),
#  ('oid', 'pg_opclass'),
#  ('oid', 'pg_opclass'),
#  ('oid', 'pg_operator'),
#  ('name', 'pg_operator'),
#  ('oid', 'pg_operator'),
#  ('"char"', 'pg_operator'),
#  ('boolean', 'pg_operator'),
#  ('boolean', 'pg_operator'),
#  ('oid', 'pg_operator'),
#  ('oid', 'pg_operator'),
#  ('oid', 'pg_operator'),
#  ('oid', 'pg_operator'),
#  ('oid', 'pg_operator'),
#  ('regproc', 'pg_operator'),
#  ('regproc', 'pg_operator'),
#  ('regproc', 'pg_operator'),
#  ('name', 'pg_opfamily'),
#  ('oid', 'pg_opfamily'),
#  ('oid', 'pg_opfamily'),
#  ('oid', 'pg_opfamily'),
#  ('text', 'pg_pltemplate'),
#  ('text', 'pg_pltemplate'),
#  ('text', 'pg_pltemplate'),
#  ('text', 'pg_pltemplate'),
#  ('ARRAY', 'pg_pltemplate'),
#  ('name', 'pg_pltemplate'),
#  ('boolean', 'pg_pltemplate'),
#  ('boolean', 'pg_pltemplate'),
#  ('text', 'pg_prepared_statements'),
#  ('boolean', 'pg_prepared_statements'),
#  ('ARRAY', 'pg_prepared_statements'),
#  ('timestamp with time zone', 'pg_prepared_statements'),
#  ('text', 'pg_prepared_statements'),
#  ('name', 'pg_prepared_xacts'),
#  ('xid', 'pg_prepared_xacts'),
#  ('text', 'pg_prepared_xacts'),
#  ('timestamp with time zone', 'pg_prepared_xacts'),
#  ('name', 'pg_prepared_xacts'),
#  ('name', 'pg_proc'),
#  ('oid', 'pg_proc'),
#  ('oid', 'pg_proc'),
#  ('oid', 'pg_proc'),
#  ('real', 'pg_proc'),
#  ('real', 'pg_proc'),
#  ('oid', 'pg_proc'),
#  ('regproc', 'pg_proc'),
#  ('boolean', 'pg_proc'),
#  ('boolean', 'pg_proc'),
#  ('boolean', 'pg_proc'),
#  ('boolean', 'pg_proc'),
#  ('boolean', 'pg_proc'),
#  ('boolean', 'pg_proc'),
#  ('"char"', 'pg_proc'),
#  ('smallint', 'pg_proc'),
#  ('smallint', 'pg_proc'),
#  ('oid', 'pg_proc'),
#  ('ARRAY', 'pg_proc'),
#  ('ARRAY', 'pg_proc'),
#  ('ARRAY', 'pg_proc'),
#  ('ARRAY', 'pg_proc'),
#  ('pg_node_tree', 'pg_proc'),
#  ('text', 'pg_proc'),
#  ('text', 'pg_proc'),
#  ('ARRAY', 'pg_proc'),
#  ('ARRAY', 'pg_proc'),
#  ('oid', 'pg_range'),
#  ('oid', 'pg_range'),
#  ('oid', 'pg_range'),
#  ('regproc', 'pg_range'),
#  ('regproc', 'pg_range'),
#  ('oid', 'pg_range'),
#  ('pg_lsn', 'pg_replication_slots'),
#  ('name', 'pg_replication_slots'),
#  ('oid', 'pg_replication_slots'),
#  ('name', 'pg_replication_slots'),
#  ('boolean', 'pg_replication_slots'),
#  ('xid', 'pg_replication_slots'),
#  ('name', 'pg_replication_slots'),
#  ('text', 'pg_replication_slots'),
#  ('xid', 'pg_replication_slots'),
#  ('boolean', 'pg_rewrite'),
#  ('"char"', 'pg_rewrite'),
#  ('oid', 'pg_rewrite'),
#  ('name', 'pg_rewrite'),
#  ('pg_node_tree', 'pg_rewrite'),
#  ('pg_node_tree', 'pg_rewrite'),
#  ('"char"', 'pg_rewrite'),
#  ('timestamp with time zone', 'pg_roles'),
#  ('oid', 'pg_roles'),
#  ('ARRAY', 'pg_roles'),
#  ('name', 'pg_roles'),
#  ('boolean', 'pg_roles'),
#  ('boolean', 'pg_roles'),
#  ('boolean', 'pg_roles'),
#  ('boolean', 'pg_roles'),
#  ('boolean', 'pg_roles'),
#  ('boolean', 'pg_roles'),
#  ('boolean', 'pg_roles'),
#  ('integer', 'pg_roles'),
#  ('text', 'pg_roles'),
#  ('name', 'pg_rules'),
#  ('text', 'pg_rules'),
#  ('name', 'pg_rules'),
#  ('name', 'pg_rules'),
#  ('oid', 'pg_seclabel'),
#  ('oid', 'pg_seclabel'),
#  ('integer', 'pg_seclabel'),
#  ('text', 'pg_seclabel'),
#  ('text', 'pg_seclabel'),
#  ('text', 'pg_seclabels'),
#  ('oid', 'pg_seclabels'),
#  ('text', 'pg_seclabels'),
#  ('text', 'pg_seclabels'),
#  ('text', 'pg_seclabels'),
#  ('oid', 'pg_seclabels'),
#  ('oid', 'pg_seclabels'),
#  ('integer', 'pg_seclabels'),
#  ('text', 'pg_settings'),
#  ('text', 'pg_settings'),
#  ('integer', 'pg_settings'),
#  ('text', 'pg_settings'),
#  ('text', 'pg_settings'),
#  ('text', 'pg_settings'),
#  ('text', 'pg_settings'),
#  ('text', 'pg_settings'),
#  ('text', 'pg_settings'),
#  ('text', 'pg_settings'),
#  ('text', 'pg_settings'),
#  ('text', 'pg_settings'),
#  ('ARRAY', 'pg_settings'),
#  ('text', 'pg_settings'),
#  ('text', 'pg_settings'),
#  ('text', 'pg_settings'),
#  ('integer', 'pg_shdepend'),
#  ('"char"', 'pg_shdepend'),
#  ('oid', 'pg_shdepend'),
#  ('oid', 'pg_shdepend'),
#  ('oid', 'pg_shdepend'),
#  ('oid', 'pg_shdepend'),
#  ('oid', 'pg_shdepend'),
#  ('oid', 'pg_shdescription'),
#  ('oid', 'pg_shdescription'),
#  ('text', 'pg_shdescription'),
#  ('oid', 'pg_shseclabel'),
#  ...]

# %% [markdown]
# ### 1.b: Print Schemas
#
# The table `INFORMATION_SCHEMA.COLUMNS` contains schema information on each.
#
# Query it to display schemas of all the public tables. In particular we are interested in the column names and data types. Make sure you only include public schemas to avoid cluttering your results with a bunch of postgres related stuff.

# %%
# Information_schema is like an automatically created and updated table of tables

# %%
# %sql SELECT table_name, table_type FROM information_schema.tables WHERE table_schema='public';
# Out:
# 63 rows affected.
# [('categories', 'BASE TABLE'),
#  ('full_order_table5', 'BASE TABLE'),
#  ('fo', 'BASE TABLE'),
#  ('table_join', 'BASE TABLE'),
#  ('full_order', 'BASE TABLE'),
#  ('customercustomerdemo', 'BASE TABLE'),
#  ('customerdemographics', 'BASE TABLE'),
#  ('customers', 'BASE TABLE'),
#  ('employees', 'BASE TABLE'),
#  ('employeeterritories', 'BASE TABLE'),
#  ('order_details', 'BASE TABLE'),
#  ('orders', 'BASE TABLE'),
#  ('products', 'BASE TABLE'),
#  ('region', 'BASE TABLE'),
#  ('shippers', 'BASE TABLE'),
#  ('shippers_tmp', 'BASE TABLE'),
#  ('suppliers', 'BASE TABLE'),
#  ('territories', 'BASE TABLE'),
#  ('usstates', 'BASE TABLE'),
#  ('table1', 'BASE TABLE'),
#  ('movies', 'BASE TABLE'),
#  ('ratings', 'BASE TABLE'),
#  ('categoriesmerged', 'BASE TABLE'),
#  ('order_table', 'BASE TABLE'),
#  ('full_ord', 'BASE TABLE'),
#  ('new_table', 'BASE TABLE'),
#  ('full_order_table', 'BASE TABLE'),
#  ('full_order_table2', 'BASE TABLE'),
#  ('full_order_table3', 'BASE TABLE'),
#  ('full_order_table4', 'BASE TABLE'),
#  ('temp_table', 'BASE TABLE'),
#  ('full_orders_', 'BASE TABLE'),
#  ('fullorders_', 'BASE TABLE'),
#  ('fullorders__', 'BASE TABLE'),
#  ('fullorders', 'BASE TABLE'),
#  ('descriptions', 'BASE TABLE'),
#  ('price', 'BASE TABLE'),
#  ('descriptions1', 'BASE TABLE'),
#  ('empterid', 'BASE TABLE'),
#  ('google_app', 'BASE TABLE'),
#  ('final', 'BASE TABLE'),
#  ('final2', 'BASE TABLE'),
#  ('final3', 'BASE TABLE'),
#  ('final4', 'BASE TABLE'),
#  ('credit_card_feature', 'BASE TABLE'),
#  ('price2', 'BASE TABLE'),
#  ('descriptions2', 'BASE TABLE'),
#  ('empterid2', 'BASE TABLE'),
#  ('final5', 'BASE TABLE'),
#  ('my_table', 'BASE TABLE'),
#  ('newregion', 'BASE TABLE'),
#  ('updatdregion', 'BASE TABLE'),
#  ('updatedregion', 'BASE TABLE'),
#  ('updatedregion1', 'BASE TABLE'),
#  ('ship_secrets', 'VIEW'),
#  ('top_5', 'VIEW'),
#  ('sessions', 'BASE TABLE'),
#  ('subscriptions', 'BASE TABLE'),
#  ('payments', 'BASE TABLE'),
#  ('students', 'BASE TABLE'),
#  ('student_practice', 'BASE TABLE'),
#  ('order_details_temp', 'BASE TABLE'),
#  ('categories_pd', 'BASE TABLE')]

# %% [markdown]
# ### 1.c: Table peek
#
# Another way of quickly looking at table information is to query the first few rows. Do this for a couple of tables, for example: `orders`, `products`, `usstates`. Display only the first 3 rows.

# %%
categories3 = %sql SELECT "CategoryID", "CategoryName", "Description" FROM categories;
categories3
# Out:
# 8 rows affected.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads'),
#  (4, 'Dairy Products', 'Cheeses'),
#  (5, 'Grains/Cereals', 'Breads, crackers, pasta, and cereal'),
#  (6, 'Meat/Poultry', 'Prepared meats'),
#  (7, 'Produce', 'Dried fruit and bean curd'),
#  (8, 'Seafood', 'Seaweed and fish')]

# %%
products = %sql SELECT * FROM products LIMIT 3;
products
# Out:
# 3 rows affected.
# [(1, 'Chai', 8, 1, '10 boxes x 30 bags', 18.0, 39, 0, 10, 1),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0, 17, 40, 25, 1),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0, 13, 70, 25, 0)]

# %% [markdown]
# As you can see, some tables (like `usstates` or `region`) contain information that is probably less prone to change than other tables (like `orders` or `order_details`). This database is well organized to avoid unnecessary duplication. Let's start digging deeper in the data.

# %% [markdown]
# ## 2: Products
#
# What products is this company selling? The `products` and `categories` tables contain information to answer this question.

# %% [markdown]
# ### 2.a: What categories of products is the company selling?
#
# Remember that PostgreSQL is case sensitive.

# %%
# %%sql
# SELECT "CategoryID", "CategoryName", "Description" FROM categories;
# Out:
# 8 rows affected.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads'),
#  (4, 'Dairy Products', 'Cheeses'),
#  (5, 'Grains/Cereals', 'Breads, crackers, pasta, and cereal'),
#  (6, 'Meat/Poultry', 'Prepared meats'),
#  (7, 'Produce', 'Dried fruit and bean curd'),
#  (8, 'Seafood', 'Seaweed and fish')]

# %% [markdown]
# ### 2.b: How many products per category ID does the catalog contain?

# %%
# %%sql
# SELECT "CategoryID", COUNT("ProductName")
# FROM products
# GROUP BY "CategoryID" ORDER BY "CategoryID";
# Out:
# 8 rows affected.
# [(1, 12), (2, 12), (3, 13), (4, 10), (5, 7), (6, 6), (7, 5), (8, 12)]

# %% [markdown]
# ### 2.c: How many NOT discontinued products per categoryID?

# %%
# %%sql
# SELECT "CategoryID", COUNT("ProductName")
# FROM products WHERE "Discontinued"=0
# GROUP BY "CategoryID" ORDER BY "CategoryID";
# Out:
# 8 rows affected.
# [(1, 9), (2, 11), (3, 13), (4, 10), (5, 6), (6, 2), (7, 4), (8, 12)]

# %% [markdown]
# ### 2.d: What are the 5 most expensive products that were not discontinued?

# %%
# %%sql
# SELECT *
# FROM products WHERE "Discontinued"=0
# ORDER BY "UnitPrice" DESC LIMIT 5;
# Out:
# 5 rows affected.
# [(38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263.5, 17, 0, 15, 0),
#  (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81.0, 40, 0, 0, 0),
#  (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62.5, 42, 0, 0, 0),
#  (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55.0, 79, 0, 0, 0),
#  (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53.0, 20, 0, 10, 0)]

# %% [markdown]
# ### 2.e: How many units of each of these 5 products are there in stock?

# %%
# %%sql
# SELECT "ProductName", "UnitsInStock"
# FROM products WHERE "Discontinued"=0
# ORDER BY "UnitPrice" DESC LIMIT 5;
# Out:
# 5 rows affected.
# [('Côte de Blaye', 17),
#  ("Sir Rodney's Marmalade", 40),
#  ('Carnarvon Tigers', 42),
#  ('Raclette Courdavault', 79),
#  ('Manjimup Dried Apples', 20)]

# %% [markdown]
# ## 3: Orders
#
# Now that we have a better understanding of products, let's start digging into orders.

# %% [markdown]
# ### 3.a: How many orders in total?

# %%
# %%sql
# SELECT * FROM orders LIMIT 1;
# Out:
# 1 rows affected.
# [(10248, 'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France')]

# %%
# %%sql
# SELECT COUNT(*) FROM orders;
# Out:
# 1 rows affected.
# [(830,)]

# %% [markdown]
# ### 3.b: Which country is receiving the most orders?

# %%
# %%sql
# SELECT "ShipCountry", COUNT("ShipCountry")
# FROM orders
# GROUP BY "ShipCountry" ORDER BY count DESC LIMIT 2;
# Out:
# 2 rows affected.
# [('USA', 122), ('Germany', 122)]

# %% [markdown]
# ### 3.c: Which country is receiving the least?

# %%
# %%sql
# SELECT "ShipCountry", COUNT("ShipCountry")
# FROM orders
# GROUP BY "ShipCountry" ORDER BY count ASC LIMIT 1;
# Out:
# 1 rows affected.
# [('Norway', 6)]

# %% [markdown]
# ### 3.d: What's the average shipping time (ShippedDate - OrderDate)?
#
# Hint: use an aggregate function

# %%
# %%sql
# SELECT AVG("ShippedDate" - "OrderDate") FROM orders;
# Out:
# 1 rows affected.
# [(Decimal('8.4919653893695921'),)]

# %% [markdown]
# ### 3.e: What customer is submitting the highest number of orders?

# %%
# %%sql
# SELECT "CustomerID", COUNT("CustomerID")
# FROM orders
# GROUP BY "CustomerID" ORDER BY count DESC LIMIT 1;
# Out:
# 1 rows affected.
# [('SAVEA', 31)]

# %% [markdown]
# ## Shifting from SQL to Pandas
#
# It's likely that, throughout the course, we'll be more familiar with Pandas syntax than SQL. Rather than racking our brains to execute complicated SQL queries when Pandas can answer this for us, what if we query data from SQL and read it into Pandas, then answer our questions that way?

# %%
import pandas as pd

# %% [markdown]
# The below cell was run earlier, where we saved the output of the SQL query as a variable `categories`. Examine the output.

# %%
categories = %sql SELECT "CategoryID", "CategoryName", "Description" FROM categories;
categories
# Out:
# 8 rows affected.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads'),
#  (4, 'Dairy Products', 'Cheeses'),
#  (5, 'Grains/Cereals', 'Breads, crackers, pasta, and cereal'),
#  (6, 'Meat/Poultry', 'Prepared meats'),
#  (7, 'Produce', 'Dried fruit and bean curd'),
#  (8, 'Seafood', 'Seaweed and fish')]

# %%
categories['CategoryName']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda2/envs/python3/lib/python3.6/site-packages/sql/run.py in __getitem__(self, key)
#     133         try:
# --> 134             return list.__getitem__(self, key)
#     135         except TypeError:
#
# TypeError: list indices must be integers or slices, not str
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-a1a6f987198b> in <module>()
# ----> 1 categories['CategoryName']
#
# ~/anaconda2/envs/python3/lib/python3.6/site-packages/sql/run.py in __getitem__(self, key)
#     136             result = [row for row in self if row[0] == key]
#     137             if not result:
# --> 138                 raise KeyError(key)
#     139             if len(result) > 1:
#     140                 raise KeyError('%d results for "%s"' % (len(result), key))
#
# KeyError: 'CategoryName'

# %% [markdown]
# We can't directly reference that column in the same way we'd usually like. Let's read this into Pandas! Note that we pass the results of a query into a variable `categories`, then force `categories` to be a Pandas DataFrame by using the `.DataFrame()` method.

# %%
categories = %sql SELECT "CategoryID", "CategoryName", "Description" FROM categories;
categories = categories.DataFrame()
categories.head()
# Out:
# 8 rows affected.
#    CategoryID    CategoryName  \
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 3           4  Dairy Products
# 4           5  Grains/Cereals
#
#                                          Description
# 0        Soft drinks, coffees, teas, beers, and ales
# 1  Sweet and savory sauces, relishes, spreads, an...
# 2                Desserts, candies, and sweet breads
# 3                                            Cheeses
# 4                Breads, crackers, pasta, and cereal

# %% [markdown]
# #### Let's recreate our answers from above by using Pandas! Make sure to show us the commands you're running to get the answers.
#
# You may find [this link](http://pandas.pydata.org/pandas-docs/stable/comparison_with_sql.html#compare-with-sql-join) particularly helpful!
#
# ## 4: Products
#
# What products is this company selling? The `products` and `categories` tables contain information to answer this question.

# %% [markdown]
# ### 4.a: What categories of products is the company selling?

# %%
categories.CategoryName
# Out:
# 0         Beverages
# 1        Condiments
# 2       Confections
# 3    Dairy Products
# 4    Grains/Cereals
# 5      Meat/Poultry
# 6           Produce
# 7           Seafood
# Name: CategoryName, dtype: object

# %% [markdown]
# ### 4.b: How many products per category ID does the catalog contain?

# %%
products = %sql SELECT * FROM products;
products = products.DataFrame()
products.head()
# Out:
# 77 rows affected.
#    ProductID                   ProductName  SupplierID  CategoryID  \
# 0          1                          Chai           8           1
# 1          2                         Chang           1           1
# 2          3                 Aniseed Syrup           1           2
# 3          4  Chef Anton's Cajun Seasoning           2           2
# 4          5        Chef Anton's Gumbo Mix           2           2
#
#        QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0   10 boxes x 30 bags      18.00            39             0            10
# 1   24 - 12 oz bottles      19.00            17            40            25
# 2  12 - 550 ml bottles      10.00            13            70            25
# 3       48 - 6 oz jars      22.00            53             0             0
# 4             36 boxes      21.35             0             0             0
#
#    Discontinued
# 0             1
# 1             1
# 2             0
# 3             0
# 4             1

# %%
products['CategoryID'].value_counts()
# Out:
# 3    13
# 8    12
# 2    12
# 1    12
# 4    10
# 5     7
# 6     6
# 7     5
# Name: CategoryID, dtype: int64

# %% [markdown]
# ### 4.c: How many NOT discontinued products per categoryID?

# %%
products[['CategoryID', 'Discontinued']].groupby('CategoryID').sum()
#sum gets rid of 0's which are discontinued, no need to specify == 0
# Out:
#             Discontinued
# CategoryID
# 1                      3
# 2                      1
# 3                      0
# 4                      0
# 5                      1
# 6                      4
# 7                      1
# 8                      0

# %% [markdown]
# ### 4.d: What are the 5 most expensive products that were not discontinued?

# %%
products[products['Discontinued'] == 1].sort_values('UnitPrice', ascending=False).head(5)
# Out:
#     ProductID              ProductName  SupplierID  CategoryID  \
# 28         29  Thüringer Rostbratwurst          12           6
# 8           9          Mishi Kobe Niku           4           6
# 27         28        Rössle Sauerkraut          12           7
# 16         17             Alice Mutton           7           6
# 52         53            Perth Pasties          24           6
#
#          QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 28  50 bags x 30 sausgs.     123.79             0             0             0
# 8       18 - 500 g pkgs.      97.00            29             0             0
# 27       25 - 825 g cans      45.60            26             0             0
# 16        20 - 1 kg tins      39.00             0             0             0
# 52             48 pieces      32.80             0             0             0
#
#     Discontinued
# 28             1
# 8              1
# 27             1
# 16             1
# 52             1

# %% [markdown]
# ### 4.e: How many units of each of these 5 products are there in stock?

# %%
new_df = products[products['Discontinued'] == 1].sort_values('UnitPrice', ascending=False).head(5)
new_df[['ProductName', 'UnitsInStock']]
# Out:
#                 ProductName  UnitsInStock
# 28  Thüringer Rostbratwurst             0
# 8           Mishi Kobe Niku            29
# 27        Rössle Sauerkraut            26
# 16             Alice Mutton             0
# 52            Perth Pasties             0

# %% [markdown]
# ## 5: Orders
#
# Now that we have a better understanding of products, let's start digging into orders.

# %% [markdown]
# ### 5.a: How many orders in total?

# %%
orders = %sql SELECT * FROM orders;
orders = orders.DataFrame()
orders.head()
# Out:
# 830 rows affected.
#    OrderID CustomerID  EmployeeID   OrderDate RequiredDate ShippedDate  \
# 0    10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
# 1    10249      TOMSP           6  1996-07-05   1996-08-16  1996-07-10
# 2    10250      HANAR           4  1996-07-08   1996-08-05  1996-07-12
# 3    10251      VICTE           3  1996-07-08   1996-08-05  1996-07-15
# 4    10252      SUPRD           4  1996-07-09   1996-08-06  1996-07-11
#
#    ShipVia  Freight                   ShipName           ShipAddress  \
# 0        3    32.38  Vins et alcools Chevalier    59 rue de l'Abbaye
# 1        1    11.61         Toms Spezialitäten         Luisenstr. 48
# 2        2    65.83              Hanari Carnes       Rua do Paço, 67
# 3        1    41.34       Victuailles en stock    2, rue du Commerce
# 4        2    51.30           Suprêmes délices  Boulevard Tirou, 255
#
#          ShipCity ShipRegion ShipPostalCode ShipCountry
# 0           Reims       None          51100      France
# 1         Münster       None          44087     Germany
# 2  Rio de Janeiro         RJ      05454-876      Brazil
# 3            Lyon       None          69004      France
# 4       Charleroi       None         B-6000     Belgium

# %% [markdown]
# ### 5.b: Which country is receiving the most orders?

# %%
orders['ShipCountry'].value_counts().head(2)
# Out:
# Germany    122
# USA        122
# Name: ShipCountry, dtype: int64

# %% [markdown]
# ### 5.c: Which country is receiving the least?

# %%
orders['ShipCountry'].value_counts().tail(1)
# Out:
# Norway    6
# Name: ShipCountry, dtype: int64

# %% [markdown]
# ### 5.d: What's the average shipping time (ShippedDate - OrderDate)?

# %%
orders['ShipTime'] = orders['ShippedDate'] - orders['OrderDate']
orders['ShipTime'].mean()
# Out:
# Timedelta('8 days 11:48:25.809641')

# %% [markdown]
# ### 5.e: What customer is submitting the highest number of orders?

# %%
orders['CustomerID'].value_counts().head(1)
# Out:
# SAVEA    31
# Name: CustomerID, dtype: int64
