# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Automated Data Collection: Lincoln Quotes
#
# _Authors: Joseph Nelson (DC)_
#
# ---
#
# For this mini-lab, you are asked to produce a list of all of Lincoln's quotes available on this page: http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1
#
# Use the `requests` and `BeautifulSoup` libraries in Python.
#
# For a bonus, collect all the quotes from each page available on Successories.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#category > div.quotedb_quotelist > div:nth-child(5) > div.quote > a   (PATH)

# %%
sites = []
for num in range(1, 14):
    url = 'https://www.successories.com/iquote/author/291/abraham-lincoln-quotes/'
    new_url = url + str(num)
    sites.append(new_url)

# %%
text = []
for url in sites:
    response = requests.get(url)
    html = response.text
    text.append(html)

# %%
#soup.find_all('div', {'class': 'quote'}).find('a').text
quotes = []
for page in text:
    soup = BeautifulSoup(page, 'lxml')
    to_parse = soup.find_all('div', {'class': 'quote'})
    for quote in to_parse:
        result = {}
        p = quote.find('a').text
        result['Quote'] = p
        quotes.append(result)

# %%
df = pd.DataFrame(quotes)
df
# Out:
#                                                  Quote
# 0    "Having thus chosen our course, without guile ...
# 1    "You have to do your own growing no matter how...
# 2    "I have been driven many times to my knees by ...
# 3    "I see a very dark cloud on America's horizon,...
# 4    "Things may come to those who wait...but only ...
# 5    "Do not worry; eat three square meals a day; s...
# 6    "He can compress the most words into the small...
# 7    "That some should be rich, shows that others m...
# 8    "Among free men there can be no successful app...
# 9       "Nothing valuable can be lost by taking time."
# 10   "Truth is generally the best vindication again...
# 11   "The shadow is what we think of it; the tree i...
# 12   "It is better to remain quiet and be thought a...
# 13   "All that I am or hope to be I owe to my angel...
# 14   "We must ask where we are and whither we are t...
# 15   "If you wish to win a man over to your ideas, ...
# 16   "I am not concerned that you have fallen -- I ...
# 17   "Force is all-conquering, but its victories ar...
# 18   "No man has a good enough memory to make a suc...
# 19   "Fourscore and seven years ago our fathers bro...
# 20   "In law it is good policy never to plead what ...
# 21   "Let me not be understood as saying that there...
# 22   "A jury too often has at least one member more...
# 23   "I am glad to know that there is a system of l...
# 24   "Kindness is the only service that will stand ...
# 25   "In times like these men should utter nothing ...
# 26   "Seriously, I do not think I fit for the presi...
# 27   "I can make a General in five minutes but a go...
# 28   "We shall nobody save or meanly lose the last ...
# 29   "The fiery trials through which we pass will l...
# ..                                                 ...
# 212  "Be not deceived. Revolutions do not go backwa...
# 213  "If you would win a man to your cause, first c...
# 214  "Better to remain silent and be thought a fool...
# 215  "If I had eight hours to chop down a tree, I'd...
# 216  "What kills a skunk is the publicity it gives ...
# 217  "I am for the people of the whole nation doing...
# 218  "I do the very best I know how, the very best ...
# 219  "To stand in silence when they should be prote...
# 220  "Human action can be modified to some extent, ...
# 221  "I like to see a man proud of the place in whi...
# 222  "[That was the speech -- delivered under a ban...
# 223  "With the catching ends the pleasure of the ch...
# 224  "We must not promise what we ought not, lest w...
# 225  "Tact is the ability to describe others as the...
# 226  "Surely God would not have created such a bein...
# 227  "The best thing about the future is that it co...
# 228  "Always bear in mind that your own resolution ...
# 229  "Nearly all men can stand adversity, but if yo...
# 230  "No matter how much cats fight, there always s...
# 231  "All my life I have tried to pluck a thistle a...
# 232  "I remember my mother's prayers and they have ...
# 233  "The dogmas of the quiet past are inadequate t...
# 234  "No man is good enough to govern another man w...
# 235  "It has been my experience that folks who have...
# 236  "These men ask for just the same thing, fairne...
# 237  "Fourscore and seven years ago our fathers bro...
# 238  "If there is anything that a man can do well, ...
# 239  "I have come to the conclusion never again to ...
# 240  "It is the eternal struggle between these two ...
# 241  "That some achieve great success, is proof to ...
#
# [242 rows x 1 columns]
